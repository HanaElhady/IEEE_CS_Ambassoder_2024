# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # 2. Data Loading

# %%
df = pd.read_csv('netflix1.csv')

# %% [markdown]
# # 3. Exploring Data

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.value_counts()
# Out:
# show_id  type     title                  director             country        date_added  release_year  rating  duration  listed_in
# s1       Movie    Dick Johnson Is Dead   Kirsten Johnson      United States  9/25/2021   2020          PG-13   90 min    Documentaries                                               1
# s6281    Movie    Below Her Mouth        April Mullen         Canada         8/1/2017    2016          TV-MA   91 min    Dramas, Independent Movies, International Movies            1
# s6276    TV Show  Behind the Newsroom    Not Given            Pakistan       9/14/2018   2015          TV-MA   1 Season  International TV Shows, Romantic TV Shows, TV Dramas        1
# s6277    TV Show  Behzat Ç.              Not Given            Turkey         5/19/2017   2010          TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Dramas           1
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df['type']
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3         Movie
# 4         Movie
#          ...
# 8785    TV Show
# 8786    TV Show
# 8787    TV Show
# 8788    TV Show
# 8789    TV Show
# Name: type, Length: 8790, dtype: object

# %%
columns = df.columns
columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'Crime TV Shows',
#        'International TV Shows', 'TV Dramas', 'TV Horror', 'Comedies',
#        'Documentaries', 'TV Mysteries', 'Independent Movies', 'Kids TV'],
#       dtype='object')

# %% [markdown]
# # 4. Data Cleaning

# %%
df["director"] = df["director"].str.replace('Not Given','')
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre
# 8786   s8798  TV Show                         Zak Storm
# 8787   s8801  TV Show                Zindagi Gulzar Hai
# 8788   s8784  TV Show                              Yoko
# 8789   s8786  TV Show                               YOM
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# ...

# %%
categories_series = df['listed_in'].str.split(',', expand=True).stack()
categories_series = categories_series.str.strip()
unique_categories = categories_series.unique()

for category in unique_categories:
    df[category] = df['listed_in'].str.contains(category)
df.drop(columns = "listed_in")
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre
# 8786   s8798  TV Show                         Zak Storm
# 8787   s8801  TV Show                Zindagi Gulzar Hai
# 8788   s8784  TV Show                              Yoko
# 8789   s8786  TV Show                               YOM
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# ...

# %% [markdown]
# # Total Content on Netflix

# %%
type_counts = df['type'].count()
type_counts
# Out:
# 8790

# %% [markdown]
# #  Top 10 countries with Netflix Content

# %%
top_countries = df['country'].value_counts()
top_countries.head(10)
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: count, dtype: int64

# %% [markdown]
# # Monthly Trend of Movie and TV Show Releases

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format='%m/%d/%Y')
sorted_df = df.sort_values(by='date_added', ascending=False)
trend[['type','title','date_added']]
# Out:
#          type                                              title date_added
# 111     Movie                                     Paradise Hills   9/9/2021
# 112     Movie                         The Women and the Murderer   9/9/2021
# 132     Movie           Blood Brothers: Malcolm X & Muhammad Ali   9/9/2021
# 41    TV Show                                        Mighty Raju   9/9/2021
# 1713    Movie                                             Cuties   9/9/2020
# ...       ...                                                ...        ...
# 5694    Movie  Power Rangers Super Megaforce: The Legendary B...   1/1/2016
# 5100    Movie                            How to Change the World   1/1/2016
# 5696    Movie  Power Rangers: Megaforce: The Robo Knight Befo...   1/1/2016
# 8615  TV Show                          Power Rangers Jungle Fury   1/1/2016
# 4253    Movie                               To and From New York   1/1/2008
#
# [8790 rows x 3 columns]

# %% [markdown]
# #  Yearly Trend of Movie and TV Show Releases

# %%
top_10_movies = df.sort_values(by='release_year', ascending=False)
top_10_movies[['type','title','date_added']]
# Out:
#          type                               title  date_added
# 6871  TV Show                        Nadiya Bakes   2/12/2021
# 541     Movie           A Second Chance:  Rivals!   7/23/2021
# 531     Movie                      Resort to Love   7/29/2021
# 532     Movie      Rurouni Kenshin: The Beginning   7/30/2021
# 533     Movie                                Mimi   7/27/2021
# ...       ...                                 ...         ...
# 6491    Movie  Why We Fight: The Battle of Russia   3/31/2017
# 6510    Movie     WWII: Report from the Aleutians   3/31/2017
# 6037    Movie                The Battle of Midway   3/31/2017
# 5698    Movie                      Prelude to War   3/31/2017
# 421   TV Show   Pioneers: First Women Filmmakers*  12/30/2018
#
# [8790 rows x 3 columns]

# %% [markdown]
# # Top 10 Movies

# %%
top_10_movies = movie.sort_values(by='rating', ascending=False).head(10)
top_10_movies['title']
# Out:
# 5862                                             Sex Doll
# 5134                                        Immoral Tales
# 6532                        You Don't Mess with the Zohan
# 5497                            Motu Patlu: King of Kings
# 4760                                         Dear Dracula
# 5348                  Little Singham aur Kaal ka Mahajaal
# 8539    LEGO Ninjago: Masters of Spinjitzu: Day of the...
# 5318                                         Leo the Lion
# 1773                                             Fearless
# 5170                                  최강전사 미니특공대 : 영웅의 탄생
# Name: title, dtype: object

# %% [markdown]
# # Top 10 TV Show

# %%
show = df.groupby('type').get_group('TV Show')
top_10_show = show.sort_values(by= 'rating', ascending=False).head(10)
top_10_show['title']
# Out:
# 8593         Oh No! It's an Alien Invasion
# 8789                                   YOM
# 8131                              Dinotrux
# 3729               Glitter Force Doki Doki
# 3712              Oggy and the Cockroaches
# 8146                    Dawn of the Croods
# 8166                 Little Witch Academia
# 8168    Pac-Man and the Ghostly Adventures
# 8190                              Fangbone
# 8192                             Miniforce
# Name: title, dtype: object

# %% [markdown]
# #  Top_10_Directors

# %%
industry = df.sort_values(by='rating', ascending=False).head(10)
top_directors = industry['director']

# %%
top_directors
# Out:
# 5862                 Sylvie Verheyde
# 6532                    Dennis Dugan
# 5134              Walerian Borowczyk
# 8539                       Not Given
# 8593                       Not Given
# 4760               Chad Van De Keere
# 5348                   Prakash Satam
# 5497                     Suhas Kadav
# 5318                     Mario Cambi
# 2397    Mark A.Z. Dippé, Eondeok Han
# Name: director, dtype: object
